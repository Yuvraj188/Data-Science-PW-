# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.tree import DecisionTreeClassifier

# %%
#loading the dataset
df = pd.read_csv('train.xls')

# %% [markdown]
# #day 19 learnings
# 1) how big data ?

# %%
df.shape#so our data has 12 columns and around 891 rows
# Out:
# (891, 12)

# %% [markdown]
# 2).how data looks like?

# %%
df.sample(8)
# Out:
#      PassengerId  Survived  Pclass  \
# 427          428         1       2
# 660          661         1       1
# 512          513         1       1
# 418          419         0       2
# 816          817         0       3
# 488          489         0       3
# 630          631         1       1
# 619          620         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 427  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
# 660                      Frauenthal, Dr. Henry William    male  50.0      2
# 512                          McGough, Mr. James Robert    male  36.0      0
# 418                         Matthews, Mr. William John    male  30.0      0
# 816                       Heininen, Miss. Wendla Maria  female  23.0      0
# 488                      Somerton, Mr. Francis William    male  30.0      0
# 630               Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# inference=>1)Age has missing values 177
#            2)Cabin has 687 missing values out of 891 rows so we will drop this
#            3)Embarked has 2 missing values

# %%
df.duplicated().sum()#no duplicate values
# Out:
# 0

# %%
# df['Family']=df['SibSp']+df['Parch']
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(columns=['PassengerId','Name','Ticket','Cabin'],inplace=True)#removing columns Passengerid,Name,Cabin

# %%
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['Survived']),
                                                 df['Survived'],
                                                  test_size=0.2,
                                                random_state=42)
X_train

# df = pd.DataFrame(trns2.fit_transform(X_train))
# print(df)
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 331       1    male  45.5      0      0   28.5000        S
# 733       2    male  23.0      0      0   13.0000        S
# 382       3    male  32.0      0      0    7.9250        S
# 704       3    male  26.0      1      0    7.8542        S
# 813       3  female   6.0      4      2   31.2750        S
# ..      ...     ...   ...    ...    ...       ...      ...
# 106       3  female  21.0      0      0    7.6500        S
# 270       1    male   NaN      0      0   31.0000        S
# 860       3    male  41.0      2      0   14.1083        S
# 435       1  female  14.0      1      2  120.0000        S
# 102       1    male  21.0      0      1   77.2875        S
#
# [712 rows x 7 columns]

# %% [markdown]
# #we will do eda later in this part but first make a pipeline so to revise the steps:
# 1)impute the missing values
# 2)feature construction
# 3)handle categorical features
# 4)feature construction
# 5)feature scaling
# 6)model training

# %%
# trns1=ColumnTransformer([('age_impute',SimpleImputer(strategy='mean'),[3]),
#                         ('embark_impute',SimpleImputer(strategy='most_frequent'),[5])],
#                         remainder='passthrough')

trns1 = ColumnTransformer([
    ('age_impute', SimpleImputer(), [2]),
    ('embark_impute', SimpleImputer(strategy='most_frequent'), [6])
], remainder='passthrough')

# %%
# trns2=ColumnTransformer([
#     ('ohe_sex_embarked',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),[1,6])
# ],remainder='passthrough')
trns2 = ColumnTransformer([
    ('ohe_sex_embarked',OneHotEncoder(sparse_output=False,handle_unknown='ignore'),[1,6])
],remainder='passthrough')
# trns2.fit(df)

# Get the number of output columns
# num_columns = trns2.transform(df).shape[1]
# num_columns = trns2.transform(df)
# num_columns
# print("Number of columns after transformation:", num_columns)#want to know no. of columns to apply scaling

# %%
trns3=ColumnTransformer([('Scaling',StandardScaler(),slice(0,None))])# Scaling all columns

# %%
trns4=DecisionTreeClassifier()

# %% [markdown]
# Creating pipeline

# %%
pipe=Pipeline([
   ('trns1',trns1),
     ('trns2',trns2),
    ('trns3',trns3),
    ('trns4',trns4)
])

# %%
pipe.fit(X_train,y_train)

# If you're doing supervised learning, you would use 'y_train' during model training
# pipe.fit(X_train, y_train)

# Print the transformed data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 pipe.fit(X_train,y_train)
#
# File D:\ana\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File D:\ana\Lib\site-packages\sklearn\pipeline.py:471, in Pipeline.fit(self, X, y, **params)
#     428 """Fit the model.
#     429
#     430 Fit all the transformers one after the other and sequentially transform the
#    (...)
#     468     Pipeline with fitted steps.
#     469 """
#     470 routed_params = self._check_method_params(method="fit", props=params)
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier

# Transformation 1: Impute missing values
trns1 = ColumnTransformer([
    ('age_impute', SimpleImputer(), [2]),
    ('embark_impute', SimpleImputer(strategy='most_frequent'), [6])
], remainder='passthrough')

# Transformation 2: One-hot encode categorical variables
trns2 = ColumnTransformer([
    ('ohe_sex_embarked', OneHotEncoder(sparse_output=False, handle_unknown='ignore'), [1, 6])
], remainder='passthrough')

# Transformation 3: Scale the features
trns3 = ColumnTransformer([('Scaling', StandardScaler(), slice(0, None))])

# Classifier
trns4 = DecisionTreeClassifier()

# Create the pipeline
pipe = Pipeline([
    ('trns1', trns1),
    ('trns2', trns2),
    ('trns3', trns3),
    ('trns4', trns4)
])

# Assuming X_train and y_train are defined
pipe.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 33
#      25 pipe = Pipeline([
#      26     ('trns1', trns1),
#      27     ('trns2', trns2),
#      28     ('trns3', trns3),
#      29     ('trns4', trns4)
#      30 ])
#      32 # Assuming X_train and y_train are defined
# ---> 33 pipe.fit(X_train, y_train)
#
# File D:\ana\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File D:\ana\Lib\site-packages\sklearn\pipeline.py:471, in Pipeline.fit(self, X, y, **params)
#     428 """Fit the model.
#     429
# ...
